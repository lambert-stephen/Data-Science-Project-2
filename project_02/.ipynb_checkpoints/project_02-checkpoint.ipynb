# %%
# Load libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
from sklearn import linear_model
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.preprocessing import StandardScaler

# %%
# Load dataset
data = pd.read_csv('merged_train.csv')
data.head()
# Out:
#   State    County  FIPS  Total Population  \
# 0    AZ    apache  4001             72346
# 1    AZ   cochise  4003            128177
# 2    AZ  coconino  4005            138064
# 3    AZ      gila  4007             53179
# 4    AZ    graham  4009             37529
#
#    Percent White, not Hispanic or Latino  \
# 0                              18.571863
# 1                              56.299492
# 2                              54.619597
# 3                              63.222325
# 4                              51.461536
#
#    Percent Black, not Hispanic or Latino  Percent Hispanic or Latino  \
# 0                               0.486551                    5.947806
# 1                               3.714395                   34.403208
# 2                               1.342855                   13.711033
# 3                               0.552850                   18.548675
# 4                               1.811932                   32.097844
#
# ...

# %%
#1. Partitions the dataset into training set and validation set,using the holdout method
#Democratic
X_train, X_test, Y_train, Y_test = train_test_split(data[['FIPS', 'Total Population','Percent White, not Hispanic or Latino', 'Percent Black, not Hispanic or Latino', 'Percent Hispanic or Latino', 'Percent Foreign Born','Percent Female','Percent Age 29 and Under','Percent Age 65 and Older','Median Household Income','Percent Unemployed','Percent Less than High School Degree', "Percent Less than Bachelor's Degree", 'Percent Rural','Party']], data['Democratic'], test_size = 0.25,train_size = 0.75,random_state = 0)
X_train, X_vals, Y_train, Y_vals = train_test_split(X_train, Y_train, test_size = 0.25, train_size = 0.75,  random_state = 0)
#Reupublican
X_train2, X_test2, Y_train2, Y_test2 = train_test_split(data[['FIPS', 'Total Population','Percent White, not Hispanic or Latino', 'Percent Black, not Hispanic or Latino', 'Percent Hispanic or Latino', 'Percent Foreign Born','Percent Female','Percent Age 29 and Under','Percent Age 65 and Older','Median Household Income','Percent Unemployed','Percent Less than High School Degree', "Percent Less than Bachelor's Degree", 'Percent Rural','Party']], data['Republican'], test_size = 0.25,train_size = 0.75,random_state = 0)
X_train2, X_vals2, Y_train2, Y_vals2 = train_test_split(X_train, Y_train, test_size = 0.25, train_size = 0.75,  random_state = 0)

#How did you partition the dataset? Paritioned the dataset using the holdout method

# %%
#2. Standardize the training set and the validation set
#Demoractic
scaler = StandardScaler()
X_train.mean()
X_train.std()
scaler.fit(X_train)
x_train_scaled = scaler.transform(X_train)
x_vals_scaled = scaler.transform(X_vals)
#Republican
scaler2 = StandardScaler()
X_train2.mean()
X_train2.std()
scaler2.fit(X_train2)
x_train_scaled2 = scaler.transform(X_train2)
x_vals_scaled2 = scaler.transform(X_vals2)

# %%
#3. Linear regression model to predict the number of votes casts for the Democratic party
model = linear_model.LinearRegression().fit(X = X_train[['Total Population','Percent White, not Hispanic or Latino', 'Percent Black, not Hispanic or Latino', 'Percent Hispanic or Latino', 'Percent Foreign Born','Percent Female','Percent Age 29 and Under','Percent Age 65 and Older','Median Household Income','Percent Unemployed','Percent Less than High School Degree', "Percent Less than Bachelor's Degree", 'Percent Rural']], y = Y_train)
# R squared (training)
Rsqr_train = model.score(X = X_train[['Total Population','Percent White, not Hispanic or Latino', 'Percent Black, not Hispanic or Latino', 'Percent Hispanic or Latino', 'Percent Foreign Born','Percent Female','Percent Age 29 and Under','Percent Age 65 and Older','Median Household Income','Percent Unemployed','Percent Less than High School Degree', "Percent Less than Bachelor's Degree", 'Percent Rural']], y = Y_train)
# R squared (validation)
Rsqr_val = model.score(X = X_vals[['Total Population','Percent White, not Hispanic or Latino', 'Percent Black, not Hispanic or Latino', 'Percent Hispanic or Latino', 'Percent Foreign Born','Percent Female','Percent Age 29 and Under','Percent Age 65 and Older','Median Household Income','Percent Unemployed','Percent Less than High School Degree', "Percent Less than Bachelor's Degree", 'Percent Rural']], y = Y_vals)
print([Rsqr_train,Rsqr_val])
# Out:
# [0.8756806637352964, 0.9102429223825241]

# %%
#3. Linear regression model to predict the number of votes casts for the Republican party
model = linear_model.LinearRegression().fit(X = X_train2[['Total Population','Percent White, not Hispanic or Latino', 'Percent Black, not Hispanic or Latino', 'Percent Hispanic or Latino', 'Percent Foreign Born','Percent Female','Percent Age 29 and Under','Percent Age 65 and Older','Median Household Income','Percent Unemployed','Percent Less than High School Degree', "Percent Less than Bachelor's Degree", 'Percent Rural']], y = Y_train2)
# R squared (training)
Rsqr_train = model.score(X = X_train2[['Total Population','Percent White, not Hispanic or Latino', 'Percent Black, not Hispanic or Latino', 'Percent Hispanic or Latino', 'Percent Foreign Born','Percent Female','Percent Age 29 and Under','Percent Age 65 and Older','Median Household Income','Percent Unemployed','Percent Less than High School Degree', "Percent Less than Bachelor's Degree", 'Percent Rural']], y = Y_train2)
# R squared (validation)
Rsqr_val = model.score(X = X_vals2[['Total Population','Percent White, not Hispanic or Latino', 'Percent Black, not Hispanic or Latino', 'Percent Hispanic or Latino', 'Percent Foreign Born','Percent Female','Percent Age 29 and Under','Percent Age 65 and Older','Median Household Income','Percent Unemployed','Percent Less than High School Degree', "Percent Less than Bachelor's Degree", 'Percent Rural']], y = Y_vals2)
print([Rsqr_train,Rsqr_val])
# Out:
# [0.8691707952883383, 0.9091337095724518]

# %%
#What is the best performing linear regression model? Democratic Linear regression model
#What is the performance of the model? The performace of the training model was less than the validation model, this is a good performance
#How did you select the variables of the model? I selected the variabes that would be most important to predict the number of Democratic votes
